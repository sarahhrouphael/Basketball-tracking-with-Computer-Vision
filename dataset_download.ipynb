# %%
# !pip install roboflow
# Out:
# ...
#      ---------------------------------------- 0.0/89.9 kB ? eta -:--:--
#      ---------------------------------------- 89.9/89.9 kB 2.6 MB/s eta 0:00:00
# ...
#   Using cached matplotlib-3.10.7-cp310-cp310-win_amd64.whl (8.1 MB)
# ...
#   Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# ...
#   Using cached pyyaml-6.0.3-cp310-cp310-win_amd64.whl (158 kB)
# ...
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#       --------------------------------------- 0.2/12.9 MB 3.5 MB/s eta 0:00:04
#       --------------------------------------- 0.2/12.9 MB 2.9 MB/s eta 0:00:05
#      - -------------------------------------- 0.4/12.9 MB 3.0 MB/s eta 0:00:05
#      - -------------------------------------- 0.5/12.9 MB 3.0 MB/s eta 0:00:05
#      - -------------------------------------- 0.6/12.9 MB 2.7 MB/s eta 0:00:05
#      -- ------------------------------------- 0.7/12.9 MB 2.8 MB/s eta 0:00:05
#      -- ------------------------------------- 0.9/12.9 MB 3.0 MB/s eta 0:00:05
# ...

# %%
# Just players and ball dataset

from roboflow import Roboflow
rf = Roboflow(api_key="8Bz5ZKQ3JlpwKAyXKdJg")
project = rf.workspace("new-workspace-besdi").project("basketball-mjp0n")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Basketball-1 in yolov8:: 100%|██████████| 5786/5786 [00:09<00:00, 632.16it/s]

# %%
# Only ball and Hoop for ball and hoop detection

from roboflow import Roboflow
rf = Roboflow(api_key="8Bz5ZKQ3JlpwKAyXKdJg")
project = rf.workspace("basketballshottracker").project("basketball-xptln")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Basketball-5 in yolov8:: 100%|██████████| 1398/1398 [00:05<00:00, 239.81it/s]

# %%
# Download High Quality of Video
# Needs Colab

from pathlib import Path

HOME = Path.cwd()
print("HOME:", HOME)

SOURCE_VIDEO_DIRECTORY = HOME / "source"

# !gdown -q https://drive.google.com/drive/folders/1eDJYqQ77Fytz15tKGdJCMeYSgmoQ-2-H -O {SOURCE_VIDEO_DIRECTORY}--folder
# Out:
# HOME: /users/eleves-b/2025/prakhar.tiwari/Downloads/CV Winner/Notebooks
# /bin/bash: line 1: gdown: command not found
