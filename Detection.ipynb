# %%
import torch

torch.cuda.is_available()
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA RTX A2000 12GB'

# %%
# Best player Detection

from ultralytics import YOLO
# Load a YOLO base model
model = YOLO("yolov8m.pt")   

model.train(
    data="Basketball-1/data.yaml",  
    epochs=200,
    imgsz=640,
    batch=16,
    device=0,
    workers=4, 
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.235 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.234 🚀 Python-3.12.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A2000 12GB, 11882MiB)
# ...

# %%
# Training Model for Basketball and Hoop detection


# Load a YOLO base model
model = YOLO("yolov8m.pt")   

model.train(
    data="/users/eleves-b/2025/prakhar.tiwari/Downloads/CV Winner/Notebooks/Ball-hoop/data.yaml",  
    epochs=200,
    imgsz=640,
    batch=16,
    device=0,
    workers=4,
    patience = 30
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.235 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.234 🚀 Python-3.12.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A2000 12GB, 11882MiB)
# ...

# %%
# Basketball - 1 best for players
# Ball Hoop best for ball and hoop

#best - train 10 & 11
